# %% [markdown]
# <a href="https://colab.research.google.com/github/lfendy/goodcodebadcode/blob/master/goodcodebadcode-liching.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # (LOCAL) collect raw data (clone repositories)

# %% [markdown]
# Use github to gather codebases:
# ruby:
# - https://github.com/rails/rails.git
# - https://github.com/eliotsykes/real-world-rails
# - https://github.com/jeromedalbert/real-world-sinatra
# - https://github.com/jeromedalbert/real-world-ruby-apps
#
# -  "https://github.com/javan/whenever.git",
#   "https://github.com/jmettraux/rufus-scheduler.git",
#   "https://github.com/resque/resque-scheduler.git",
#   "https://github.com/Rykian/clockwork.git",
#   "https://github.com/ddollar/foreman.git",
#   "https://github.com/resque/resque.git",
#   "https://github.com/mperham/sidekiq.git",
#   "https://github.com/bbatsov/rubocop.git",
#   "https://github.com/premailer/premailer.git",
#   "https://github.com/Mange/roadie.git",
#   "https://github.com/busyloop/lolcat.git",
#   "https://github.com/Homebrew/brew.git",
#   "https://github.com/octopress/octopress.git",
#   "https://github.com/jekyll/jekyll.git",
#   "https://github.com/middleman/middleman.git",
#   "https://github.com/sass/sass.git",
#   "https://github.com/pry/pry.git",
#   "https://github.com/Gazler/githug.git",
#   "https://github.com/adamsanderson/qwandry.git",
#   "https://github.com/bkeepers/dotenv.git",
#   "https://github.com/grosser/smusher.git",
#   "https://github.com/grosser/ruco.git",
#   "https://github.com/ruby/rake.git",
#   "https://github.com/ruby/rdoc.git",
#   "https://github.com/jneen/rouge.git",
#   "https://github.com/rubychan/coderay.git",
#   "https://github.com/github/markup.git",
#   "https://github.com/gettalong/kramdown.git",
#   "https://github.com/haml/haml.git",
#   "https://github.com/troessner/reek.git",
#   "https://github.com/capistrano/capistrano.git",
#   "https://github.com/mina-deploy/mina.git",
#   "https://github.com/hashicorp/vagrant.git",
#   "https://github.com/puppetlabs/puppet.git",
#   "https://github.com/macournoyer/thin.git",
#   "https://github.com/defunkt/unicorn.git",
#   "https://github.com/puma/puma.git",
#   "https://github.com/chef/chef.git",
#   "https://github.com/presidentbeef/brakeman.git",
#   "https://github.com/alexreisner/geocoder.git",
#   "https://github.com/tmuxinator/tmuxinator.git",
#   "https://github.com/athityakumar/colorls.git",
#   "https://github.com/toy/image_optim.git",
#   "https://github.com/skywinder/github-changelog-generator.git",
#   "https://github.com/ryanb/ruby-warrior.git",
#   "https://github.com/mame/optcarrot.git",
#   "https://github.com/adamcooke/procodile.git",
#   "https://github.com/grosser/pru.git",
#   "https://github.com/pawurb/termit.git",
#   "https://github.com/JacobEvelyn/friends.git",
#   "https://github.com/weppos/whois.git",
#   "https://github.com/htty/htty.git",
#   "https://github.com/benbalter/word-to-markdown.git",
#   "https://github.com/xijo/reverse_markdown.git",
#   "https://github.com/jstrait/beats.git",
#   "https://github.com/pazdera/catpix.git",
#   "https://github.com/soffes/hue.git",
#   "https://github.com/johnnyt/cowsay.git",
#   "https://github.com/sferik/t.git",
#   "https://github.com/CocoaPods/CocoaPods.git"
#
# javascript / typescript?
# - https://github.com/eliotsykes/real-world-ember
# - https://github.com/jeromedalbert/real-world-react-apps
# - https://github.com/tryghost/Ghost
# - https://github.com/ericf/open-marriage
# - https://github.com/thanpolas/nodeON
# - https://github.com/thanpolas/crude
# - https://github.com/NodeBB/NodeBB
# - https://github.com/emgram769/livechan-js
# - https://github.com/pencilblue/pencilblue
# - https://github.com/Actionhero/Actionhero
# - https://github.com/balderdashy/sails
# - https://github.com/abuiles/borrowers
# - https://github.com/emberjax/cast
# - https://github.com/gcollazo/ember-cli-addon-search
# - https://github.com/broerse/ember-cli-blog
# - https://github.com/givanse/ember-cli-simple-auth-devise
# - https://github.com/ember-cli/ember-cli-todos
# - https://github.com/stefanpenner/ember-jobs
# - https://github.com/ember-cli/ember-twiddle
# - https://github.com/ember-weekend/ember-weekend
# - https://github.com/emberobserver/client
# - https://github.com/abuiles/facturas-client
# - https://github.com/HospitalRun/hospitalrun-frontend
# - https://github.com/huboard/huboard-web
# - https://github.com/hummingbird-me/kitsu-tools
# - https://github.com/alisdair/team-time-zone
# - https://github.com/wordset/wordset-ui
# - https://github.com/1ven/do.git
# - https://github.com/Automattic/wp-calypso.git
# - https://github.com/DevAlien/dripr-ui.git
# - https://github.com/FormidableLabs/react-music.git
# - https://github.com/FormidableLabs/spectacle.git
# - https://github.com/HVF/franchise.git
# - https://github.com/Khan/perseus.git
# - https://github.com/KrateLabs/KrateLabs-App.git
# - https://github.com/LeoAJ/react-iTunes-search.git
# - https://github.com/SKempin/reactjs-tmdb-app.git
# - https://github.com/WebbyLab/itsquiz-wall.git
# - https://github.com/afghl/dribble-demo.git
# - https://github.com/afonsopacifer/react-pomodoro.git
# - https://github.com/andrewngu/sound-redux.git
# - https://github.com/antoinejaussoin/retro-board.git
# - https://github.com/benoitvallon/react-native-nw-react-calculator.git
# - https://github.com/browniefed/pdxlivebus.git
# - https://github.com/captbaritone/winamp2-js.git
# - https://github.com/chvin/react-tetris.git
# - https://github.com/docker/kitematic.git
# - https://github.com/dockunit/platform.git
# - https://github.com/echenley/react-news.git
# - https://github.com/fcsonline/react-transmission.git
# - https://github.com/feednext/feednext.git
# - https://github.com/fullstackreact/react-yelp-clone.git
# - https://github.com/getguesstimate/guesstimate-app.git
# - https://github.com/gothinkster/react-redux-realworld-example-app.git
# - https://github.com/gpbl/isomorphic500.git
# - https://github.com/guyellis/plant.git
# - https://github.com/hoppula/refire-forum.git
# - https://github.com/insin/lifequote.git
# - https://github.com/insin/react-hn.git
# - https://github.com/ismaelgt/english-accents-map.git
# - https://github.com/koodilehto/invoice-frontend.git
# - https://github.com/limichange/flex-editor.git
# - https://github.com/lkazberova/react-photo-feed.git
# - https://github.com/paulhoughton/mortgage-mobx.git
# - https://github.com/paulhoughton/mortgage.git
# - https://github.com/pearofducks/foodprocessor.git
# - https://github.com/pl12133/react-solitaire.git
# - https://github.com/project-bobon/bobonroastprofile.git
# - https://github.com/ritoplz/ritoplz.git
# - https://github.com/rwieruch/favesound-redux.git
# - https://github.com/skidding/flatris.git
# - https://github.com/skidding/illustrated-algorithms.git
# - https://github.com/sprintly/sprintly-ui.git
# - https://github.com/stevenhauser/i-have-to-return-some-videotapes.git
# - https://github.com/torontojs/torontojs.com.git
# - https://github.com/web-pal/react-trello-board.git
# - https://github.com/zeit/hyper.git
# - https://github.com/rwieruch/favesound-mobx
#
#
# kotlin / java:
# - https://github.com/square/okhttp
# - https://github.com/mockito/mockito
# - https://github.com/iluwatar/java-design-patterns
# - https://github.com/ReactiveX/RxJava
# - https://github.com/google/guava
# - https://github.com/spring-projects/spring-framework
# - https://github.com/elastic/elasticsearch
# - https://github.com/apache/commons-lang
# - https://github.com/apache/hadoop
# - https://github.com/JetBrains/kotlin
# - https://github.com/shadowsocks/shadowsocks-android
# - https://github.com/android/architecture-samples
# - https://github.com/square/leakcanary
# - https://github.com/ReactiveX/RxKotlin
# - https://github.com/InsertKoinIO/koin
# - https://github.com/ssseasonnn/RxDownload
# - https://github.com/dbacinski/Design-Patterns-In-Kotlin

# %%
remotes = [
  #kotlin java
  "https://github.com/square/okhttp",
  #"https://github.com/mockito/mockito", #does not have a master 
  "https://github.com/iluwatar/java-design-patterns",
  #"https://github.com/ReactiveX/RxJava", #does not have a master
  "https://github.com/google/guava",
  "https://github.com/spring-projects/spring-framework",
  "https://github.com/elastic/elasticsearch",
  "https://github.com/apache/commons-lang",
  "https://github.com/apache/hadoop",
  "https://github.com/JetBrains/kotlin",
  "https://github.com/shadowsocks/shadowsocks-android",
  "https://github.com/android/architecture-samples",
  "https://github.com/square/leakcanary",
  "https://github.com/ReactiveX/RxKotlin",
  "https://github.com/InsertKoinIO/koin",
  "https://github.com/ssseasonnn/RxDownload",
  "https://github.com/dbacinski/Design-Patterns-In-Kotlin",
  #rb
  "https://github.com/javan/whenever.git",
  "https://github.com/jmettraux/rufus-scheduler.git",
  "https://github.com/resque/resque-scheduler.git",
  "https://github.com/Rykian/clockwork.git",
  "https://github.com/ddollar/foreman.git",
  "https://github.com/resque/resque.git",
  "https://github.com/mperham/sidekiq.git",
  "https://github.com/bbatsov/rubocop.git",
  "https://github.com/premailer/premailer.git",
  "https://github.com/Mange/roadie.git",
  "https://github.com/busyloop/lolcat.git",
  "https://github.com/Homebrew/brew.git",
  "https://github.com/octopress/octopress.git",
  "https://github.com/jekyll/jekyll.git",
  "https://github.com/middleman/middleman.git",
  "https://github.com/sass/sass.git",
  "https://github.com/pry/pry.git",
  "https://github.com/Gazler/githug.git",
  "https://github.com/adamsanderson/qwandry.git",
  "https://github.com/bkeepers/dotenv.git",
  "https://github.com/grosser/smusher.git",
  "https://github.com/grosser/ruco.git",
  "https://github.com/ruby/rake.git",
  "https://github.com/ruby/rdoc.git",
  "https://github.com/jneen/rouge.git",
  "https://github.com/rubychan/coderay.git",
  "https://github.com/github/markup.git",
  "https://github.com/gettalong/kramdown.git",
  "https://github.com/haml/haml.git",
  "https://github.com/troessner/reek.git",
  "https://github.com/capistrano/capistrano.git",
  "https://github.com/mina-deploy/mina.git",
  "https://github.com/hashicorp/vagrant.git",
  "https://github.com/puppetlabs/puppet.git",
  "https://github.com/macournoyer/thin.git",
  "https://github.com/defunkt/unicorn.git",
  "https://github.com/puma/puma.git",
  "https://github.com/chef/chef.git",
  "https://github.com/presidentbeef/brakeman.git",
  "https://github.com/alexreisner/geocoder.git",
  "https://github.com/tmuxinator/tmuxinator.git",
  "https://github.com/athityakumar/colorls.git",
  "https://github.com/toy/image_optim.git",
  "https://github.com/skywinder/github-changelog-generator.git",
  "https://github.com/ryanb/ruby-warrior.git",
  "https://github.com/mame/optcarrot.git",
  "https://github.com/adamcooke/procodile.git",
  "https://github.com/grosser/pru.git",
  "https://github.com/pawurb/termit.git",
  "https://github.com/JacobEvelyn/friends.git",
  "https://github.com/weppos/whois.git",
  "https://github.com/htty/htty.git",
  "https://github.com/benbalter/word-to-markdown.git",
  "https://github.com/xijo/reverse_markdown.git",
  "https://github.com/jstrait/beats.git",
  "https://github.com/pazdera/catpix.git",
  "https://github.com/soffes/hue.git",
  "https://github.com/johnnyt/cowsay.git",
  "https://github.com/sferik/t.git",
  "https://github.com/CocoaPods/CocoaPods.git"
  # js / ts
  "https://github.com/tryghost/Ghost",
  "https://github.com/ericf/open-marriage",
  "https://github.com/thanpolas/nodeON",
  "https://github.com/thanpolas/crude",
  "https://github.com/NodeBB/NodeBB",
  "https://github.com/emgram769/livechan-js",
  "https://github.com/pencilblue/pencilblue",
  "https://github.com/Actionhero/Actionhero",
  "https://github.com/balderdashy/sails",
  "https://github.com/abuiles/borrowers",
  "https://github.com/emberjax/cast",
  "https://github.com/gcollazo/ember-cli-addon-search",
  "https://github.com/broerse/ember-cli-blog",
  "https://github.com/givanse/ember-cli-simple-auth-devise",
  "https://github.com/ember-cli/ember-cli-todos",
  "https://github.com/stefanpenner/ember-jobs",
  "https://github.com/ember-cli/ember-twiddle",
  "https://github.com/ember-weekend/ember-weekend",
  "https://github.com/emberobserver/client",
  "https://github.com/abuiles/facturas-client",
  "https://github.com/HospitalRun/hospitalrun-frontend",
  "https://github.com/huboard/huboard-web",
  "https://github.com/hummingbird-me/kitsu-tools",
  "https://github.com/alisdair/team-time-zone",
  "https://github.com/wordset/wordset-ui",
  "https://github.com/1ven/do.git",
  "https://github.com/Automattic/wp-calypso.git",
  "https://github.com/DevAlien/dripr-ui.git",
  "https://github.com/FormidableLabs/react-music.git",
  "https://github.com/FormidableLabs/spectacle.git",
  "https://github.com/HVF/franchise.git",
  "https://github.com/Khan/perseus.git",
  "https://github.com/KrateLabs/KrateLabs-App.git",
  "https://github.com/LeoAJ/react-iTunes-search.git",
  "https://github.com/SKempin/reactjs-tmdb-app.git",
  "https://github.com/WebbyLab/itsquiz-wall.git",
  "https://github.com/afghl/dribble-demo.git",
  "https://github.com/afonsopacifer/react-pomodoro.git",
  "https://github.com/andrewngu/sound-redux.git",
  "https://github.com/antoinejaussoin/retro-board.git",
  "https://github.com/benoitvallon/react-native-nw-react-calculator.git",
  "https://github.com/browniefed/pdxlivebus.git",
  "https://github.com/captbaritone/winamp2-js.git",
  "https://github.com/chvin/react-tetris.git",
  "https://github.com/docker/kitematic.git",
  "https://github.com/dockunit/platform.git",
  "https://github.com/echenley/react-news.git",
  "https://github.com/fcsonline/react-transmission.git",
  "https://github.com/feednext/feednext.git",
  "https://github.com/fullstackreact/react-yelp-clone.git",
  "https://github.com/getguesstimate/guesstimate-app.git",
  "https://github.com/gothinkster/react-redux-realworld-example-app.git",
  "https://github.com/gpbl/isomorphic500.git",
  "https://github.com/guyellis/plant.git",
  "https://github.com/hoppula/refire-forum.git",
  "https://github.com/insin/lifequote.git",
  "https://github.com/insin/react-hn.git",
  "https://github.com/ismaelgt/english-accents-map.git",
  "https://github.com/koodilehto/invoice-frontend.git",
  "https://github.com/limichange/flex-editor.git",
  "https://github.com/lkazberova/react-photo-feed.git",
  "https://github.com/paulhoughton/mortgage-mobx.git",
  "https://github.com/paulhoughton/mortgage.git",
  "https://github.com/pearofducks/foodprocessor.git",
  "https://github.com/pl12133/react-solitaire.git",
  "https://github.com/project-bobon/bobonroastprofile.git",
  "https://github.com/ritoplz/ritoplz.git",
  "https://github.com/rwieruch/favesound-redux.git",
  "https://github.com/skidding/flatris.git",
  "https://github.com/skidding/illustrated-algorithms.git",
  "https://github.com/sprintly/sprintly-ui.git",
  "https://github.com/stevenhauser/i-have-to-return-some-videotapes.git",
  "https://github.com/torontojs/torontojs.com.git",
  "https://github.com/web-pal/react-trello-board.git",
  "https://github.com/zeit/hyper.git",
  "https://github.com/rwieruch/favesound-mobx"
]

# %%
def get_dir_name(url_name):
  return url_name.split('/')[-1].replace(".git", "")

test_url = "https://asdf/asdfasdfasdf/xzcvzxcv/vbnm.git"
print("vbnm should == ", get_dir_name(test_url))

def get_ext(filename):
  return filename.split('.')[-1]

test_filename = "asd/asd/f/sdafas/df/asdfsadfasdf/filename.extension"
print("extension should == ", get_ext(test_filename))
# Out:
# vbnm should ==  vbnm
# extension should ==  extension

# %%
# !mkdir -p data/raw
# !mkdir -p data/labeled

# %%
# clone 
for src_url in remotes:
  print(src_url)
  # !git -C data/raw clone --depth=1 --single-branch --branch=master $src_url

# %%
# remove .git folders collect dir_names
dir_names = []
for src_url in remotes:
  dir_name = get_dir_name(src_url)
  print(dir_name)
  dir_names.append(dir_name)
  # !rm -rf data/raw/$dir_name/.git

# %% [markdown]
# ```
# !find $src_loc -type f -name "*.$ext" | xargs -I%% echo -e "%%\n__snakeme__%%" | sed '/__snakeme__/s/\//_/g' | sed "s@__snakeme__@$lang_loc@g" | xargs -r -l2 -- cp -f
# ```
#     # this is a hack:
#     # - find... will get us [
#     #   "data/raw/project/folder1/folder2/somefile.kt",
#     #   "data/raw/project/folder3/someotherfile.kt"]
#     ##### (this needs a duplicate, a marker for regex (__snakeme__) and a new line '\n' so `sed` can replace '/' with '_' ONLY on relevant lines)
#     # - change to [
#     #   "data/raw/project/folder1/folder2/somefile.kt\n__snakeme__data/raw/project/folder1/folder2/somefile.kt",
#     #   "data/raw/project/folder3/someotherfile.kt\n__snakeme__data/raw/project/folder3/someotherfile.kt"]
#     #####
#     # - change to [
#     #   "data/raw/project/folder1/folder2/somefile.kt\n__snakeme__data_raw_project_folder1_folder2_somefile.kt",
#     #   "data/raw/project/folder3/someotherfile.kt\n__snakeme__data_raw_project_folder3_someotherfile.kt"]
#     #####
#     # - change to [
#     #   "data/raw/project/folder1/folder2/somefile.kt\ndata/labeled/data_raw_project_folder1_folder2_somefile.kt",
#     #   "data/raw/project/folder3/someotherfile.kt\ndata/labeled/data_raw_project_folder3_someotherfile.kt"]
#     #####
#     # - pass to `xargs` with:
#     #   -r: so we don't execute xargs if stream is empty
#     #   -l2: pass the arguments to xargs, 2 at a time
#     #   cp -f: copy force (overwrite always)

# %%
dict_ext_to_lang = {
  "kt": "kotlin",
  "java": "java",
  "rb": "ruby",
  "ts": "typescript",
  "js": "javascript"
}

raw_loc = "data/raw/"
labeled_loc = "data/labeled/"

# remove spaces from dir and remove spaces from filenames
# try this next time: find /tmp/ -depth -name "* *" -execdir rename 's/ /_/g' "{}" \;
# !find $raw_loc -name "* *" -type d | rename 's/ /_/g'    # do the directories first
# !find $raw_loc -name "* *" -type f | rename 's/ /_/g'

# copy to appropriate language folders (flattened with path)
for dir_name in dir_names:
  print(dir_name)
  for el in dict_ext_to_lang.items():
    ext = el[0]
    lang = el[1]
    print(lang)
    src_loc = raw_loc + dir_name
    lang_loc = labeled_loc + lang + "/"
    # !mkdir -p $lang_loc    
    # !find $src_loc -type f -name "*.$ext" | xargs -I%% echo -e "%%\n__snakeme__%%" | sed '/__snakeme__/s/\//_/g' | sed "s@__snakeme__@$lang_loc@g" | xargs -r -l2 -- cp -f
    print(lang + " done")
  print(dir_name + " done")

# %% [markdown]
# # (LOCAL) Create Parquett / H5 files from labeled

# %%
# Locally label data
root_dir = "/code"
# %pwd
# Out:
# '/code/data/labeled'

# %%
dict_ext_to_lang = {
  "kt": "kotlin",
  "java": "java",
  "rb": "ruby",
  "ts": "typescript",
  "js": "javascript"
}

labeled_dir = root_dir + "/data/labeled"

# %cd $labeled_dir

for ext in dict_ext_to_lang:
    lang = dict_ext_to_lang[ext] 
    num_files = !ls $lang | wc -l
    print(f'{lang}: {num_files}')
# Out:
# /code/data/labeled
# kotlin: ['57869']
# java: ['38859']
# ruby: ['15481']
# typescript: ['1135']
# javascript: ['13585']

# %%
max_num_files = 90000;
labeled_dirs = !find $labeled_dir -mindepth 1 -maxdepth 1 -type d
print(labeled_dirs)

data = []

for lang_dir in labeled_dirs:
    lang = get_dir_name(lang_dir)
    lang_files = !find $lang_dir -type f -maxdepth 1 | head -n $max_num_files
    #lang_files = !ls -dU $lang_dir/* | head -n $max_num_files
    for lang_file in lang_files:
        my_file = open(lang_file, 'r')
        my_content = ''
        try:
            my_content = my_file.read()            
            data.append([lang, my_content])
        except UnicodeDecodeError:
            print(lang_file)
        my_file.close()
# Out:
# ['/code/data/labeled/typescript', '/code/data/labeled/java', '/code/data/labeled/kotlin', '/code/data/labeled/javascript', '/code/data/labeled/ruby']
# /code/data/labeled/javascript/raw_js_NodeBB_public_vendor_xregexp_unicode_unicode-base.js
# /code/data/labeled/javascript/raw_js_NodeBB_public_vendor_xregexp_unicode_unicode-blocks.js
# /code/data/labeled/javascript/raw_js_NodeBB_public_vendor_xregexp_unicode_unicode-categories.js
# /code/data/labeled/javascript/raw_js_NodeBB_public_vendor_xregexp_unicode_unicode-properties.js
# /code/data/labeled/javascript/raw_js_NodeBB_public_vendor_xregexp_unicode_unicode-scripts.js

# %%
import pandas as pd
data
df = pd.DataFrame(data, columns = ['Language', 'Content'])

# %%
df.to_hdf('gcbc_data_all.h5', key='df', mode='w', complevel=9, complib='blosc:lz4hc') #this doesn't compress text

df.to_parquet('gcbc_data_all.parquet.gzip', compression='gzip')

# %%
# Out:
#      Language                                            Content
# 0  typescript  /**\n * Internal dependencies\n */\nimport con...
# 1  typescript  import { produce } from 'immer';\n\nimport { m...
# 2        java  /*\n * Copyright 2017-2020 the original author...
# 3        java  package org.koin.java;\n\nimport kotlin.Lazy;\...
# 4      kotlin  package org.koin.android.experimental.dsl\n\ni...
# 5      kotlin  package org.koin.android.experimental.dsl\n\ni...
# 6  javascript  (function() {\n    // Functions\n    // ======...
# 7  javascript  module.exports = {\n    "parserOptions": {\n  ...
# 8        ruby  require 'erb'\nrequire 'ostruct'\nrequire 'jav...
# 9        ruby  require 'erb'\nrequire 'ostruct'\nrequire 'jav...

# %% [markdown]
# # (COLAB) Setup with files already in Gdrive

# %%
# Start from unzipped files in the gdrive
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/Shared drives/Cash Eng /ML Infrastructure/05 passion projects/goodcodebadcode/"
base_dir = root_dir + 'fastai-v3/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
 # !curl -s https://course.fast.ai/setup/colab | bash
# Out:
# Updating fastai...
# Done.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.text import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %cd "/content/gdrive/Shared drives/Cash Eng /ML Infrastructure/05 passion projects/goodcodebadcode/data/"
# %pwd
# %ls
# Out:
# /content/gdrive/Shared drives/Cash Eng /ML Infrastructure/05 passion projects/goodcodebadcode/data
# gcbc_data_10k.h5.zip        gcbc_data_15k.parquet.gzip  gcbc_data.h5
# gcbc_data_10k.parquet.gzip  gcbc_data_all.h5            labeled/
# gcbc_data_15k.h5            gcbc_data_all.h5.zip
# gcbc_data_15k.h5.zip        gcbc_data_all.parquet.gzip

# %%
df = pd.read_parquet('gcbc_data_all.parquet.gzip')

# %%
df
# Out:
#           Language                                            Content
# 0       typescript  /**\n * Internal dependencies\n */\nimport con...
# 1       typescript  import { produce } from 'immer';\n\nimport { m...
# 2       typescript  /**\n * External dependencies\n */\nimport typ...
# 3       typescript  /**\n * External Dependencies\n */\nimport { R...
# 4       typescript  // Local files\nimport { TitleResponseData, Ca...
# ...            ...                                                ...
# 126919        ruby  require 'cocoapods/user_interface/error_report...
# 126920        ruby  require 'active_support/core_ext/hash/indiffer...
# 126921        ruby  require 'active_support/core_ext/array'\nrequi...
# 126922        ruby  module Pod\n  class Resolver\n    # A small co...
# 126923        ruby  require 'delegate'\nmodule Pod\n  class Specif...
#
# [126924 rows x 2 columns]

# %% [markdown]
# # (COLAB) Dataframe loaded: columns: "Type" and "Content", now do some analysis

# %%
# calc functions

def dfcalc_num_lines(in_df):
  in_df['num_lines']= [x.count('\n') + 1 for x in in_df.Content]
  return in_df.num_lines.tolist()
  
given_df = pd.DataFrame({'Content': ['1', '2\n2', '3\n3\n3']})
print('\n\n dfcalc_num_lines:\n [1, 2, 3] should ==\n', dfcalc_num_lines(given_df))

def dfcalc_empty_lines(in_df):
  in_df['num_empty_lines'] = [reduce(lambda acc, el: acc if(len(el.strip()) != 0) else (acc+1), x.split('\n'), 0) for x in in_df.Content]
  return in_df.num_empty_lines.tolist()

def dfcalc_non_empty_lines(in_df):
  in_df['num_non_empty_lines'] = [reduce(lambda acc, el: acc if(len(el.strip()) == 0) else (acc+1), x.split('\n'), 0) for x in in_df.Content]
  return in_df.num_non_empty_lines.tolist()

given_df = pd.DataFrame({'Content': ['0', '1\n', '\n1', '2\n\n', '\n2\n', '2\n\n']})
print('\n\n dfcalc_empty_lines:\n [0, 1, 1, 2, 2, 2] should ==\n', dfcalc_empty_lines(given_df))
print('\n\n dfcalc_non_empty_lines:\n [1, 1, 1, 1, 1, 1] should ==\n', dfcalc_non_empty_lines(given_df))


def dfcalc_max_line_len(in_df):
  in_df['max_line_len'] = [len(max(x.split('\n'), key=len)) for x in in_df.Content]
  return in_df.max_line_len.tolist()

given_df = pd.DataFrame({'Content': ['1\n55555\n333\n4444\n22']})
print('\n\n dfcalc_max_line_len:\n [5] should ==\n', dfcalc_max_line_len(given_df))

def dfcalc_num_chars(in_df):
  in_df['num_chars']= [reduce(lambda acc, el: acc + len(el), x.split('\n'), 0) for x in in_df.Content]
  return in_df.num_chars.tolist()

given_df = pd.DataFrame({'Content': ['1\n55555\n333\n4444\n22']})
print(f'\n\n dfcalc_num_chars:\n [{1+5+3+4+2}] should ==\n', dfcalc_num_chars(given_df))
# Out:
#  dfcalc_num_lines:
#  [1, 2, 3] should ==
#  [1, 2, 3]
#
#
#  dfcalc_empty_lines:
#  [0, 1, 1, 2, 2, 2] should ==
#  [0, 1, 1, 2, 2, 2]
#
#
#  dfcalc_non_empty_lines:
#  [1, 1, 1, 1, 1, 1] should ==
#  [1, 1, 1, 1, 1, 1]
#
#
#  dfcalc_max_line_len:
#  [5] should ==
#  [5]
#
#
#  dfcalc_num_chars:
#  [15] should ==
#  [15]

# %%
# calc functions (continued)

def dfcalc_char_types(in_df):
  # white spaces
  in_df['num_spaces'] = [x.count(' ') for x in in_df.Content]
  in_df['num_tabs'] = [x.count('\t') for x in in_df.Content]
  in_df['num_white_spaces'] = in_df.num_tabs + in_df.num_spaces
  
  # alphanumeric
  in_df['num_upcases'] = in_df.Content.str.count(r'[A-Z]')
  in_df['num_locases'] = in_df.Content.str.count(r'[a-z]')
  in_df['num_numerics'] = in_df.Content.str.count(r'[0-9]')
  
  # symbols
  in_df['num_non_alphanums'] = in_df.Content.str.count(r'[^a-zA-Z0-9 ]')
  in_df['num_curly_brackets'] = in_df.Content.str.count('{') + in_df.Content.str.count('}')
  in_df['num_square_brackets'] = in_df.Content.str.count('\[') + in_df.Content.str.count('\]')
  in_df['num_parentheses'] = in_df.Content.str.count('\(') + in_df.Content.str.count('\)')
  in_df['num_semicolons'] = in_df.Content.str.count(';')
  in_df['num_colons'] = in_df.Content.str.count(':')
  in_df['num_single_quotes'] = in_df.Content.str.count('\'')
  in_df['num_double_quotes'] = in_df.Content.str.count('\"')
  in_df['num_backticks'] = in_df.Content.str.count('`')
  in_df['num_hashes'] = in_df.Content.str.count('#')
  in_df['num_fwd_slashes'] = in_df.Content.str.count('/')
  in_df['num_back_slashes'] = in_df.Content.str.count('\\\\')
  in_df['num_percents'] = in_df.Content.str.count('%')
  in_df['num_ats'] = in_df.Content.str.count('@')
  in_df['num_bangs'] = in_df.Content.str.count('!')
  in_df['num_question_marks'] = in_df.Content.str.count('\?')
  in_df['num_dashes'] = in_df.Content.str.count('-')
  in_df['num_underscores'] = in_df.Content.str.count('_')
  
  in_df['avg_pline_chars'] = in_df.num_chars / in_df.num_non_empty_lines

  # white space
  in_df['avg_pline_spaces'] = in_df.num_spaces / in_df.num_non_empty_lines
  in_df['avg_pline_tabs'] = in_df.num_tabs / in_df.num_non_empty_lines
  in_df['avg_pline_white_spaces'] = in_df.num_white_spaces / in_df.num_non_empty_lines

  # alphanumeric
  in_df['avg_pline_upcase'] = in_df.num_upcases / in_df.num_non_empty_lines
  in_df['avg_pline_locase'] = in_df.num_locases / in_df.num_non_empty_lines
  in_df['avg_pline_numerics'] = in_df.num_numerics / in_df.num_non_empty_lines

  # symbols
  in_df['avg_pline_non_alphanums'] = in_df.num_non_alphanums / in_df.num_non_empty_lines
  in_df['avg_pline_curly_brackets'] = in_df.num_curly_brackets / in_df.num_non_empty_lines
  in_df['avg_pline_square_brackets'] = in_df.num_square_brackets / in_df.num_non_empty_lines
  in_df['avg_pline_parentheses'] = in_df.num_parentheses / in_df.num_non_empty_lines
  in_df['avg_pline_semicolons'] = in_df.num_semicolons / in_df.num_non_empty_lines
  in_df['avg_pline_colons'] = in_df.num_colons / in_df.num_non_empty_lines
  in_df['avg_pline_single_quotes'] = in_df.num_single_quotes / in_df.num_non_empty_lines
  in_df['avg_pline_double_quotes'] = in_df.num_double_quotes / in_df.num_non_empty_lines
  in_df['avg_pline_backticks'] = in_df.num_backticks / in_df.num_non_empty_lines
  in_df['avg_pline_hashes'] = in_df.num_hashes / in_df.num_non_empty_lines
  in_df['avg_pline_fwd_slashes'] = in_df.num_fwd_slashes / in_df.num_non_empty_lines
  in_df['avg_pline_back_slashes'] = in_df.num_back_slashes / in_df.num_non_empty_lines
  in_df['avg_pline_percents'] = in_df.num_percents / in_df.num_non_empty_lines
  in_df['avg_pline_ats'] = in_df.num_ats / in_df.num_non_empty_lines
  in_df['avg_pline_bangs'] = in_df.num_bangs / in_df.num_non_empty_lines
  in_df['avg_pline_question_marks'] = in_df.num_question_marks / in_df.num_non_empty_lines
  in_df['avg_pline_dashes'] = in_df.num_dashes / in_df.num_non_empty_lines
  in_df['avg_pline_underscores'] = in_df.num_underscores / in_df.num_non_empty_lines
  return in_df

given_content = '' 
given_content += ' '                      #  1 space
given_content += '\t\t'                   #  2 tabs
given_content += "ABC"                    #  3 upcase 
given_content += 'defg'                   #  4 locase
given_content += '01234'                  #  5 numeric
given_content += '{}{}{}'                 #  6 curly
given_content += '[][][]['                #  7 square brackets
given_content += '()()()()'               #  8 parentheses
given_content += ';;;;;;;;;'              #  9 semicolons
given_content += '::::::::::'             # 10 colons
given_content += '\'\'\'\'\'\'\'\'\'\'\'' # 11 quotes
given_content += '""""""""""""'           # 12 doublequotes
given_content += '`````````````'          # 13 backticks
given_content += '##############'         # 14 hash
given_content += '///////////////'        # 15 fwd slash
given_content += '\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\' # 16 back slash
given_content += '%%%%%%%%%%%%%%%%%'      # 17 percent
given_content += '@@@@@@@@@@@@@@@@@@'     # 18 at
given_content += '!!!!!!!!!!!!!!!!!!!'    # 19 bang 
given_content += '????????????????????'   # 20 question mark 
given_content += '---------------------'  # 21 dashes
given_content += '______________________' # 22 underscores

given_df = pd.DataFrame({'Content': [given_content], 'num_chars': [len(given_content)], 'num_non_empty_lines': [1]})

then_df = dfcalc_char_types(given_df)
print('\n dfcalc_char_types-space:\n [1] should ==\n', then_df.num_spaces.tolist())
print('\n dfcalc_char_types-tab:\n [2] should ==\n', then_df.num_tabs.tolist())
print(f'\n dfcalc_char_types-whitespaces:\n [{1+2}] should ==\n', then_df.num_white_spaces.tolist())
print('\n dfcalc_char_types-upcase:\n [3] should ==\n', then_df.num_upcases.tolist())
print('\n dfcalc_char_types-locase:\n [4] should ==\n', then_df.num_locases.tolist())
print('\n dfcalc_char_types-numerics:\n [5] should ==\n', then_df.num_numerics.tolist())
print('\n dfcalc_char_types-curlys:\n [6] should ==\n', then_df.num_curly_brackets.tolist())
print('\n dfcalc_char_types-squares:\n [7] should ==\n', then_df.num_square_brackets.tolist())
print('\n dfcalc_char_types-parens:\n [8] should ==\n', then_df.num_parentheses.tolist())
print('\n dfcalc_char_types-semicolons:\n [9] should ==\n', then_df.num_semicolons.tolist())
print('\n dfcalc_char_types-colons:\n [10] should ==\n', then_df.num_colons.tolist())
print('\n dfcalc_char_types-quotes:\n [11] should ==\n', then_df.num_single_quotes.tolist())
print('\n dfcalc_char_types-doublequotes:\n [12] should ==\n', then_df.num_double_quotes.tolist())
print('\n dfcalc_char_types-backticks:\n [13] should ==\n', then_df.num_backticks.tolist())
print('\n dfcalc_char_types-hashes:\n [14] should ==\n', then_df.num_hashes.tolist())
print('\n dfcalc_char_types-fwdslashes:\n [15] should ==\n', then_df.num_fwd_slashes.tolist())
print('\n dfcalc_char_types-backslashes:\n [16] should ==\n', then_df.num_back_slashes.tolist())
print('\n dfcalc_char_types-percents:\n [17] should ==\n', then_df.num_percents.tolist())
print('\n dfcalc_char_types-ats:\n [18] should ==\n', then_df.num_ats.tolist())
print('\n dfcalc_char_types-bangs:\n [19] should ==\n', then_df.num_bangs.tolist())
print('\n dfcalc_char_types-questionmarks:\n [20] should ==\n', then_df.num_question_marks.tolist())
print('\n dfcalc_char_types-dashes:\n [21] should ==\n', then_df.num_dashes.tolist())
print('\n dfcalc_char_types-underscores:\n [22] should ==\n', then_df.num_underscores.tolist())
# Out:
#  dfcalc_char_types-space:
#  [1] should ==
#  [1]
#
#  dfcalc_char_types-tab:
#  [2] should ==
#  [2]
#
#  dfcalc_char_types-whitespaces:
#  [3] should ==
#  [3]
#
#  dfcalc_char_types-upcase:
#  [3] should ==
#  [3]
#
#  dfcalc_char_types-locase:
#  [4] should ==
#  [4]
#
#  dfcalc_char_types-numerics:
#  [5] should ==
#  [5]
#
#  dfcalc_char_types-curlys:
#  [6] should ==
#  [6]
#
#  dfcalc_char_types-squares:
#  [7] should ==
#  [7]
#
#  dfcalc_char_types-parens:
#  [8] should ==
#  [8]
#
#  dfcalc_char_types-semicolons:
#  [9] should ==
#  [9]
#
#  dfcalc_char_types-colons:
#  [10] should ==
#  [10]
#
#  dfcalc_char_types-quotes:
#  [11] should ==
#  [11]
#
#  dfcalc_char_types-doublequotes:
#  [12] should ==
#  [12]
#
#  dfcalc_char_types-backticks:
#  [13] should ==
#  [13]
#
#  dfcalc_char_types-hashes:
#  [14] should ==
#  [14]
#
#  dfcalc_char_types-fwdslashes:
#  [15] should ==
#  [15]
#
#  dfcalc_char_types-backslashes:
#  [16] should ==
#  [16]
#
#  dfcalc_char_types-percents:
#  [17] should ==
#  [17]
#
#  dfcalc_char_types-ats:
#  [18] should ==
#  [18]
#
#  dfcalc_char_types-bangs:
#  [19] should ==
#  [19]
#
#  dfcalc_char_types-questionmarks:
#  [20] should ==
#  [20]
#
#  dfcalc_char_types-dashes:
#  [21] should ==
#  [21]
#
#  dfcalc_char_types-underscores:
#  [22] should ==
#  [22]

# %%
def dfcalc(in_df):
  dfcalc_num_lines(in_df)
  dfcalc_num_chars(in_df)
  dfcalc_max_line_len(in_df)
  dfcalc_empty_lines(in_df)
  dfcalc_non_empty_lines(in_df)
  dfcalc_char_types(in_df)
  return in_df

# %%
df = dfcalc(df)
df
# Out:
#           Language  ... avg_pline_underscores
# 0       typescript  ...              0.210526
# 1       typescript  ...              0.000000
# 2       typescript  ...              0.000000
# 3       typescript  ...              0.000000
# 4       typescript  ...              0.000000
# ...            ...  ...                   ...
# 126919        ruby  ...              0.367788
# 126920        ruby  ...              0.388430
# 126921        ruby  ...              0.985915
# 126922        ruby  ...              1.228571
# 126923        ruby  ...              0.906667
#
# [126924 rows x 56 columns]
